# %% [markdown]
# # Model Demonstrations
#
# Here we use the imported functions from `demos/analysis.py` for convenient plotting of our circular and bottleneck models, imported from `code/nsmodel.py`, with the ability to tamper with any parameters.

# %%
# Necessary imports:

import sys
sys.path.append('../code/')
from nsmodel import *
from analysis import *

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Visualizing the evolution of the traffic lane cells over time
#
# The `SpaceTimePlot` function streamlines the creation of time evolution plots of the circular and bottleneck Nagel–Schreckenberg models. This function defaults to modeling the circular traffic system, and will switch to the bottleneck model by using the argument: `bottleneck = True`.

# %% [markdown]
# ## Circular Model System Density:
#
# Varying the `system_density` argument demonstrates the transition from smooth laminar flow to considerable traffic congestion.

# %% [markdown]
# ### Laminar flow at low density:

# %%
SpaceTimePlot(cells=100, system_density=0.05, timesteps=100)

# %% [markdown]
# ### Transitioning traffic flow with increasing density:

# %%
SpaceTimePlot(cells=100, system_density=0.1, timesteps=100)
SpaceTimePlot(cells=100, system_density=0.12, timesteps=100)
SpaceTimePlot(cells=100, system_density=0.14, timesteps=100)

# %% [markdown]
# ### Traffic congestion at higher densities:

# %%
SpaceTimePlot(cells=100, system_density=0.2, timesteps=100)
SpaceTimePlot(cells=100, system_density=0.3, timesteps=100)
SpaceTimePlot(cells=100, system_density=0.5, timesteps=100)

# %% [markdown]
# ## Bottleneck Model Car Inflow Probabiltity:
#
# The `inflow` parameter is fundamental parameter to the bottleneck model, setting the probability that a car will enter the first traffic cell (if empty) with each timestep.
# Varying the `inflow` argument determines how frequently cars enter the traffic lane, i.e. how crowded the system becomes. \
#  \
# Note that the system density will not be constant in the bottleneck model, as the boundaries are open. Thus, the `system_density` argument only impacts the starting number of cars and doesn't hold much of an impact after the intitialization period.

# %%
SpaceTimePlot(cells=100, system_density=0.2, timesteps=100, bottleneck=True, inflow=0.1) 
SpaceTimePlot(cells=100, system_density=0.2, timesteps=100, bottleneck=True, inflow=0.5)
SpaceTimePlot(cells=100, system_density=0.2, timesteps=100, bottleneck=True, inflow=0.9)

# %% [markdown]
# ## Analyzing Traffic Flow with respect to Car Density
#
# The `PlotDensityFlow` function collects and plots several runs of traffic flow vs. density data from the
# circular Nagel–Schreckenberg model, with each run varying the system density. This data is found using the `DensityFlowResults` function, which takes samples of specific indeces over time to gather a larger variety of local traffic density.  \
#  \
# Note: This function can have a high run time.

# %%
PlotDensityFlow(cells=10**3, timesteps=10**2)
